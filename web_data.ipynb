# %%
import pandas as pd
import cleaning_funciones as cf

# %%
df1 = cf.load_data("Datasets/df_final_web_data_pt_1.txt")
df2 = cf.load_data("Datasets/df_final_web_data_pt_2.txt")

# %%
df1.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
df1.shape
# Out:
# (343141, 5)

# %%
df2.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
df2.shape
# Out:
# (412264, 5)

# %%
# Merge
df_web = cf.merge_web_data(df1, df2)

# %%
print(df_web.shape)
df_web.head()
# Out:
# (755405, 5)
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
df_web = cf.clean_columns(df_web)
df_web.columns
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], dtype='object')

# %%
# ver duplicados
df_web.duplicated().sum()
# Out:
# np.int64(10764)

# %%
df_web = cf.remove_duplicates(df_web)

print(df_web.duplicated().sum())

df_web.shape
# Out:
# 0
# (744641, 5)

# %%
# fechas para que no sean texto y pase a formato datetime de pandas
df_web = cf.datetime_conversion(df_web, 'date_time')

df_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 744641 entries, 0 to 755404
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     744641 non-null  int64
#  1   visitor_id    744641 non-null  object
#  2   visit_id      744641 non-null  object
#  3   process_step  744641 non-null  object
#  4   date_time     744641 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.1+ MB

# %%
# process_step
df_web = cf.sort_data(df_web)
df_web.head(10)
# Out:
#         client_id             visitor_id                      visit_id  \
# 285515        169  201385055_71273495308  749567106_99161211863_557568
# 285514        169  201385055_71273495308  749567106_99161211863_557568
# 285513        169  201385055_71273495308  749567106_99161211863_557568
# 285512        169  201385055_71273495308  749567106_99161211863_557568
# 285511        169  201385055_71273495308  749567106_99161211863_557568
# 628456        336    64757908_3400128256  649044751_80905125055_554468
# 628331        336    64757908_3400128256  649044751_80905125055_554468
# 442857        546  475037402_89828530214    731811517_9330176838_94847
# 442856        546  475037402_89828530214    731811517_9330176838_94847
# 442855        546  475037402_89828530214    731811517_9330176838_94847
#
#        process_step           date_time
# 285515        start 2017-04-12 20:19:36
# 285514       step_1 2017-04-12 20:19:45
# 285513       step_2 2017-04-12 20:20:31
# ...

# %%
# índice reset
df_web = cf.reset_dataframe_index(df_web)

df_web.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0        169  201385055_71273495308  749567106_99161211863_557568
# 1        169  201385055_71273495308  749567106_99161211863_557568
# 2        169  201385055_71273495308  749567106_99161211863_557568
# 3        169  201385055_71273495308  749567106_99161211863_557568
# 4        169  201385055_71273495308  749567106_99161211863_557568
#
#   process_step           date_time
# 0        start 2017-04-12 20:19:36
# 1       step_1 2017-04-12 20:19:45
# 2       step_2 2017-04-12 20:20:31
# 3       step_3 2017-04-12 20:22:05
# 4      confirm 2017-04-12 20:23:09

# %%
cf.check_nulls(df_web)
# Out:
#               null_count  null_percentage
# client_id              0              0.0
# visitor_id             0              0.0
# visit_id               0              0.0
# process_step           0              0.0
# date_time              0              0.0

# %%
df_web['process_step'].unique()
# Out:
# array(['start', 'step_1', 'step_2', 'step_3', 'confirm'], dtype=object)

# %%
df_web.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time       datetime64[ns]
# dtype: object

# %%
print(df_web['date_time'].min())
print(df_web['date_time'].max())
# Out:
# 2017-03-15 00:03:03
# 2017-06-20 23:59:57

# %%
df_web.shape
# Out:
# (744641, 5)

# %%
df_web['client_id'].nunique() # usuarios repetidos
# Out:
# 120157

# %%
df_web['visit_id'].nunique() # visitas del usuario
# Out:
# 158095

# %%
cf.export_clean_csv(df_web, "clean_web_data.csv")
